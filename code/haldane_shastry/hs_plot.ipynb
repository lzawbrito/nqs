# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("hs_outputs.txt", skiprows=1)
nqs_en_x, nqs_en_y, analytical_en_x, analytical_en_y = data[:,0], data[:,1], data[:,2], data[:,3]

# %%
plt.plot(nqs_en_x, nqs_en_y, label="NQS") 
plt.plot(analytical_en_x, analytical_en_y, label="analytical") 
plt.legend()
plt.show()
